# %%
import numpy as np
import tensorflow as tf

X = np.arange(-20, 21, 2, dtype=np.float32)
y = 2 * X + 5

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,)),
    tf.keras.layers.Dense(1)
])

model.compile(
    loss="mae",
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
    metrics=["mae"]
)

model.fit(X, y, epochs=500, verbose=0)

loss, mae = model.evaluate(X, y, verbose=0)
print("MAE:", mae)

print("Example prediction for x=10:", model.predict(np.array([10], dtype=np.float32), verbose=0))
# Out:
# MAE: 0.5742591619491577
# Example prediction for x=10: [[25.395624]]

# %%
import tensorflow as tf
import numpy as np

# Load Fashion-MNIST
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# Normalize
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Improved model
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(28, 28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation="relu"),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])

model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer="adam",
    metrics=["accuracy"]
)

model.fit(x_train, y_train, epochs=15, validation_split=0.1, verbose=1)

loss, acc = model.evaluate(x_test, y_test, verbose=0)
print("Test accuracy:", acc)
# Out:
# Epoch 1/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8266 - loss: 0.4828 - val_accuracy: 0.8497 - val_loss: 0.4253
# Epoch 2/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8666 - loss: 0.3627 - val_accuracy: 0.8645 - val_loss: 0.3640
# Epoch 3/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 966us/step - accuracy: 0.8792 - loss: 0.3264 - val_accuracy: 0.8680 - val_loss: 0.3643
# Epoch 4/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 976us/step - accuracy: 0.8873 - loss: 0.3032 - val_accuracy: 0.8782 - val_loss: 0.3431
# Epoch 5/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 972us/step - accuracy: 0.8930 - loss: 0.2872 - val_accuracy: 0.8862 - val_loss: 0.3114
# Epoch 6/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8967 - loss: 0.2724 - val_accuracy: 0.8847 - val_loss: 0.3163
# Epoch 7/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 960us/step - accuracy: 0.9036 - loss: 0.2568 - val_accuracy: 0.8857 - val_loss: 0.3125
# Epoch 8/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 919us/step - accuracy: 0.9071 - loss: 0.2455 - val_accuracy: 0.8867 - val_loss: 0.3225
# Epoch 9/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 909us/step - accuracy: 0.9110 - loss: 0.2357 - val_accuracy: 0.8893 - val_loss: 0.3091
# Epoch 10/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 994us/step - accuracy: 0.9137 - loss: 0.2235 - val_accuracy: 0.8907 - val_loss: 0.3115
# Epoch 11/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 957us/step - accuracy: 0.9180 - loss: 0.2153 - val_accuracy: 0.8897 - val_loss: 0.3311
# Epoch 12/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 946us/step - accuracy: 0.9198 - loss: 0.2076 - val_accuracy: 0.8928 - val_loss: 0.3234
# Epoch 13/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 946us/step - accuracy: 0.9235 - loss: 0.2026 - val_accuracy: 0.8950 - val_loss: 0.3282
# Epoch 14/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 965us/step - accuracy: 0.9255 - loss: 0.1932 - val_accuracy: 0.8855 - val_loss: 0.3586
# Epoch 15/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 2s 957us/step - accuracy: 0.9286 - loss: 0.1869 - val_accuracy: 0.8873 - val_loss: 0.3560
# Test accuracy: 0.8838000297546387

# %% [markdown]
# # Test Purpose
